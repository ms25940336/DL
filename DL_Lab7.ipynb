# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samples = 100
timesteps = 10
features = 5
X = np.random.rand(samples, timesteps, features)
print("Dataset shape:", X.shape)
# Out:
# Dataset shape: (100, 10, 5)

# %%
sequence = X[0]
plt.plot(sequence)
plt.title("Example Sequence")
plt.xlabel("Time Step")
plt.ylabel("Feature Value")
print("Q1")
plt.show()
# Out:
# Q1

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
print("Q2")
model = Sequential()
model.add(SimpleRNN(
32,
activation='tanh',
input_shape=(10,5)
))
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Q2
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)        │ (None, 32)             │         1,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,315 (5.14 KB)
#  Trainable params: 1,315 (5.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y = np.random.randint(0,3,100)

# %%
model.compile(
optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy']
)

# %%
history = model.fit(
X,
y,
epochs=5,
batch_size=8,
validation_split=0.2
)
# Out:
# Epoch 1/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.2875 - loss: 1.1799 - val_accuracy: 0.3500 - val_loss: 1.1696
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3875 - loss: 1.1435 - val_accuracy: 0.2500 - val_loss: 1.2105
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3625 - loss: 1.0987 - val_accuracy: 0.4000 - val_loss: 1.1545
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3625 - loss: 1.0722 - val_accuracy: 0.4000 - val_loss: 1.1616
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4000 - loss: 1.0496 - val_accuracy: 0.3500 - val_loss: 1.1875

# %%
import matplotlib.pyplot as plt
print("Q3")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Training","Validation"])
plt.show()
# Out:
# Q3
